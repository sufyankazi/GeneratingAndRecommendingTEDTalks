# %%
import requests
from requests_oauthlib import OAuth1
import cnfg
from selenium import webdriver
from random import random
import time
import re
import pickle
import gensim
import numpy
import matplotlib.pyplot as plt
import pandas as pd

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils

from sklearn.manifold import TSNE
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.cluster import KMeans, AgglomerativeClustering,SpectralClustering
from sklearn.decomposition import LatentDirichletAllocation, NMF
from sklearn.metrics import silhouette_score, pairwise

from tensorflow.python.client import device_lib

import gc
import nltk

from flask import Flask
# Out:
# Using TensorFlow backend.
# /home/sufyan/anaconda3/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# <h1>Resources</h1>

# %% [markdown]
# 1) https://machinelearningmastery.com/text-generation-lstm-recurrent-neural-networks-python-keras/
# 2) http://docs.aws.amazon.com/AWSEC2/latest/UserGuide/recognize-expanded-volume-linux.html
# 3) https://www.youtube.com/channel/UCYO_jab_esuFRV4b17AJtAw/search?query=neural

# %% [markdown]
# <h1>Get first 1000 of TED channel</h1>

# %%
APIkey='AIzaSyCtlhQyzMtwi6CIQx4lcVydl8WXzaYr58g'
ChannelID='UCAuUUnT6oDeKwE6v1NGQxug'
MaxResults=50
pageToken=''
AllResponse=[]
for i in range(51):
    url='https://www.googleapis.com/youtube/v3/search?order=date&part=snippet&channelId={}&maxResults={}&key={}&pageToken={}'\
        .format(ChannelID, MaxResults, APIkey, pageToken)
    response = requests.get(url)
    r=response.json()
    AllResponse.append(r)
    pageToken=r['nextPageToken']

# %%
AllVideos=[]
for x in AllResponse:
    z=x
    for i in range(MaxResults):
        if x['items'][i]['id']['kind']=='youtube#video':
            AllVideos.append(x['items'][i]['id']['videoId'])

# %%
AllSubs=[]
misses=0
for i in range(len(AllVideos)):
    url='https://www.youtube.com/watch?v={}'.format(AllVideos[i])
    browser=webdriver.Chrome('/home/sufyan/Metis/Week7/chromedriver')
    browser.get(url)
    try:
        time.sleep(2)
        browser.find_element_by_xpath('//yt-icon[contains(@class,"ytd-menu-renderer")]').click()
        time.sleep(1)
        browser.find_element_by_xpath('//yt-formatted-string[contains(@class,"ytd-menu-service-item-renderer")]').click()
        time.sleep(1)
        text=browser.find_element_by_xpath('//*[@id="body"]').text
        browser.close()
        AllSubs.append(text)
    except:
        misses+=1
        browser.close()
#             time.sleep(2)
#             browser.find_element_by_xpath('//*[@id="action-panel-overflow-button"]').click()
#             time.sleep(500)
#             browser.find_element_by_xpath('//*[@id="action-panel-overflow-menu"]/li[2]/button/span').click()
#             time.sleep(2)
#             browser.find_element_by_xpath(
        #             browser.find_element_by_xpath('//*[@id="action-panel-overflow-button"]').click()

# %% [markdown]
# <h3>Pickle First Set</h3>

# %%
# pickle.dump(AllSubs, open("First1kSubs.pickle.dat", "wb"))

# %% [markdown]
# <h1>Get results from TEDx</h1>

# %%
APIkey='AIzaSyCtlhQyzMtwi6CIQx4lcVydl8WXzaYr58g'
ChannelID='UCsT0YIqwnpJCM-mx7-gSA4Q'
MaxResults=50
pageToken=''
SecondResponse=[]
for i in range(51):
    url='https://www.googleapis.com/youtube/v3/search?order=date&part=snippet&channelId={}&maxResults={}&key={}&pageToken={}'\
        .format(ChannelID, MaxResults, APIkey, pageToken)
    response = requests.get(url)
    r=response.json()
    SecondResponse.append(r)
    pageToken=r['nextPageToken']

# %%
SecondVideos=[]
for x in SecondResponse:
    z=x
    for i in range(MaxResults):
        if x['items'][i]['id']['kind']=='youtube#video':
            SecondVideos.append(x['items'][i]['id']['videoId'])

# %%
SecondSubs=[]
misses=0
for i in range(len(AllVideos)):
    url='https://www.youtube.com/watch?v={}'.format(SecondVideos[i])
    browser=webdriver.Chrome('/home/sufyan/Metis/Week7/chromedriver')
    browser.get(url)
#     browser.find_element_by_css_selector("#action-panel-overflow-button").click()
    try:
        time.sleep(2)
        browser.find_element_by_xpath('//yt-icon[contains(@class,"ytd-menu-renderer")]').click()
        time.sleep(1)
        browser.find_element_by_xpath('//yt-formatted-string[contains(@class,"ytd-menu-service-item-renderer")]').click()
        time.sleep(1)
        text=browser.find_element_by_xpath('//*[@id="body"]').text
        browser.close()
        SecondSubs.append(text)
    except:
        misses+=1
#         misses was 58
        browser.close()

# %% [markdown]
# <h3>Pickle Second Set</h3>

# %%
# pickle.dump(AllSubs, open("TEDxsubs.pickle.dat", "wb"))

# %% [markdown]
# <h1>Load PickleFiles</h1>

# %%
# SecondSubs=pickle.load('Tedxsubs.pickle.dat')
# AllSubs=pickle.loads('First1kSubs.pickle.dat')
with open('First1kSubs.pickle.dat', 'rb') as pickle_file:
    AllSubs = pickle.load(pickle_file)
with open('TEDxsubs.pickle.dat', 'rb') as pickle_file:
    SecondSubs = pickle.load(pickle_file)

# %% [markdown]
# <h1>Combine and Clean subs</h1>

# %%
totalchars=0
for i in SecondSubs:
    totalchars+=len(i)
for i in AllSubs:
    totalchars+=len(i)
totalchars
# Out:
# 10504046

# %%
AllSubs=AllSubs+SecondSubs

# %% [markdown]
# <h3>Cleaning For LSTM</h3>

# %%
LSTMSubs=[]
LSTMString=''
for i in range(len(AllSubs)):
    tempstring=AllSubs[i]
    tempstring=tempstring.replace('\n', ' ')
    tempstring=tempstring.replace('\\', ' ')
    for char in '0123456789:':
        tempstring=re.sub(char,'',tempstring)
    LSTMSubs.append(tempstring)
    tempstring=tempstring.replace('  ', ' ')
    tempstring=tempstring.replace('  ', ' ')
    LSTMString=(LSTMString+tempstring).strip()+'\n'
LSTMString[:1000]
pickle.dump(LSTMString, open("TedAllTalksString.pickle.dat", "wb"))

# %% [markdown]
# <h3>Cleaning for other NLP</h3>

# %%
ProcessedSubs=[]
SubString=''
LemmaString=''
for i in range(len(AllSubs)):
    tempstring=AllSubs[i]
    tempstring=tempstring.replace('\n', ' ')
    for char in '0123456789!:",;-':
        tempstring=re.sub(char,'',tempstring)
    tempstring=re.sub('\?','',tempstring)
    tempstring=re.sub('\.','',tempstring)
    ProcessedSubs.append(tempstring)
    tempstring=tempstring.replace('\'', '')
    tempstring=tempstring.replace('  ', ' ')
    SubString=(SubString+tempstring).strip()+'\n'
    SubString=SubString.lower()

l=nltk.wordnet.WordNetLemmatizer()#doesn't work well at all
stemmer=nltk.stem.PorterStemmer()

SubString[:1000]
SubStopList=SubString.split('\n')
SubList=[]
StopWords=nltk.corpus.stopwords.words("english")
for i in range(len(SubStopList)):
    templist=[]
    for word in SubStopList[i].split():    
        if not word in StopWords:
#             templist.append(stemmer.stem(word)) #stemming didn't produce any better tsne models and resulted in increased numbers of words not found in google's vector space.
            templist.append(word)
    SubList.append(templist)

# %%
SubList[2]
# Out:
# ['taste',
#  'words',
#  'question',
#  'caught',
#  'surprise',
#  'summer',
#  'giving',
#  'talk',
#  'literary',
#  'festival',
#  'afterwards',
#  'signing',
#  'books',
#  'teenage',
#  'girl',
#  'came',
#  'friend',
#  'asked',
#  'told',
#  'people',
#  'experience',
#  'overlap',
#  'senses',
#  'could',
#  'hear',
#  'colors',
#  'see',
#  'sounds',
#  'many',
#  'writers',
#  'fascinated',
#  'subject',
#  'included',
#  'cut',
#  'bit',
#  'impatiently',
#  'said',
#  'yeah',
#  'know',
#  'called',
#  'synesthesia',
#  'learned',
#  'school',
#  'mom',
#  'reading',
#  'book',
#  'says',
#  'theres',
#  'lots',
#  'food',
#  'ingredients',
#  'long',
#  'dinner',
#  'scene',
#  'gets',
#  'hungry',
#  'every',
#  'page',
#  'thinking',
#  'come',
#  'dont',
#  'get',
#  'hungry',
#  'write',
#  'thought',
#  'maybe',
#  'maybe',
#  'could',
#  'taste',
#  'words',
#  'make',
#  'sense',
#  'actually',
#  'make',
#  'sense',
#  'ever',
#  'since',
#  'childhood',
# ...

# %% [markdown]
# <h1>Modeling</h1>

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
WV = gensim.models.Word2Vec(iter=10, workers=8) 
WV.build_vocab(SubList)
WV.train(SubList, total_words=WV.corpus_count, epochs=WV.iter)
pickle.dump(WV, open("word2vec.pickle.dat", "wb"))
# Out:
# 2017-11-10 10:51:05,873 : INFO : collecting all words and their counts
# 2017-11-10 10:51:05,874 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-11-10 10:51:06,051 : INFO : collected 27333 word types from a corpus of 795286 raw words and 691 sentences
# 2017-11-10 10:51:06,052 : INFO : Loading a fresh vocabulary
# 2017-11-10 10:51:06,111 : INFO : min_count=5 retains 12055 unique words (44% of original 27333, drops 15278)
# 2017-11-10 10:51:06,112 : INFO : min_count=5 leaves 756666 word corpus (95% of original 795286, drops 38620)
# 2017-11-10 10:51:06,144 : INFO : deleting the raw counts dictionary of 27333 items
# 2017-11-10 10:51:06,146 : INFO : sample=0.001 downsamples 42 most-common words
# 2017-11-10 10:51:06,147 : INFO : downsampling leaves estimated 720566 word corpus (95.2% of prior 756666)
# 2017-11-10 10:51:06,148 : INFO : estimated required memory for 12055 words and 100 dimensions: 15671500 bytes
# ...

# %%
# model = gensim.models.Word2Vec.load('GoogleNews-vectors-negative300.bin')
word_vectors = gensim.models.keyedvectors.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True)
# Out:
# 2017-11-10 11:24:30,431 : INFO : loading projection weights from GoogleNews-vectors-negative300.bin
# 2017-11-10 11:25:04,806 : INFO : loaded (3000000, 300) matrix from GoogleNews-vectors-negative300.bin

# %%
googledf=[]
for word in WV.wv.vocab:
    try:
        googledf.append(word_vectors[word])
    except:
        pass
googledf=pd.DataFrame(googledf)
googledf[:5]

# %%
with open('word2vec.pickle.dat', 'rb') as pickle_file:
    WV = pickle.load(pickle_file)

# %%
def tsne_plot(model, wordlist=None, perplexity=40, random_state=23, labeling=False):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []
    missed=0
    if wordlist==None:
        wordlist=model.wv.vocab
    for word in wordlist:
        try:    
            tokens.append(model[word])
            labels.append(word)
        except:
            print('{} words not found in model vocab.'.format(missed))
            missed+=1
    
    tsne_model = TSNE(perplexity=perplexity, n_components=2, init='pca', n_iter=2500, random_state=random_state)
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(16, 16)) 
    for i in range(len(x)//10):
        plt.scatter(x[i*10],y[i*10])
        if labeling==True:
            plt.annotate(labels[i*10],
                         xy=(x[i*10], y[i*10]),
                         xytext=(5, 2),
                         textcoords='offset points',
                         ha='right',
                         va='bottom')
    plt.show()
    return(missed)

# %%
tsne_plot(WV)
# tsne_model=TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
# tsne_model.fit_transform(WV)
# Out:
# 0

# %%
tsne_plot(word_vectors, WV.wv.vocab, labeling=True)
del word_vectors #helps free memory
# Out:
# 0 words not found in model vocab.
# 1 words not found in model vocab.
# 2 words not found in model vocab.
# 3 words not found in model vocab.
# 4 words not found in model vocab.
# 5 words not found in model vocab.
# 6 words not found in model vocab.
# 7 words not found in model vocab.
# 8 words not found in model vocab.
# 9 words not found in model vocab.
# 10 words not found in model vocab.
# 11 words not found in model vocab.
# 12 words not found in model vocab.
# 13 words not found in model vocab.
# 14 words not found in model vocab.
# 15 words not found in model vocab.
# 16 words not found in model vocab.
# 17 words not found in model vocab.
# 18 words not found in model vocab.
# 19 words not found in model vocab.
# 20 words not found in model vocab.
# 21 words not found in model vocab.
# 22 words not found in model vocab.
# 23 words not found in model vocab.
# 24 words not found in model vocab.
# 25 words not found in model vocab.
# 26 words not found in model vocab.
# ...

# %%
tsne_plot(word_vectors, WV.wv.vocab, labeling=True)
del word_vectors #helps free memory
# Out:
# 0 words not found in model vocab.
# 1 words not found in model vocab.
# 2 words not found in model vocab.
# 3 words not found in model vocab.
# 4 words not found in model vocab.
# 5 words not found in model vocab.
# 6 words not found in model vocab.
# 7 words not found in model vocab.
# 8 words not found in model vocab.
# 9 words not found in model vocab.
# 10 words not found in model vocab.
# 11 words not found in model vocab.
# 12 words not found in model vocab.
# 13 words not found in model vocab.
# 14 words not found in model vocab.
# 15 words not found in model vocab.
# 16 words not found in model vocab.
# 17 words not found in model vocab.
# 18 words not found in model vocab.
# 19 words not found in model vocab.
# 20 words not found in model vocab.
# 21 words not found in model vocab.
# 22 words not found in model vocab.
# 23 words not found in model vocab.
# 24 words not found in model vocab.
# 25 words not found in model vocab.
# 26 words not found in model vocab.
# ...

# %% [markdown]
# <h1>TF+TF-IDF</h1>

# %%
N_fea=500
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, max_features=N_fea, stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(LSTMSubs)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

# %%
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=N_fea, stop_words='english')
tf = tf_vectorizer.fit_transform(LSTMSubs)
tf_feature_names = tf_vectorizer.get_feature_names()

# %% [markdown]
# <h1>LDA+NMF</h1>

# %%
nmf = NMF(n_components=20, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd')
nmf_out=nmf.fit_transform(tfidf)

# %%
df=pd.DataFrame()
for i in range(len(nmf_out)):
    df['doc{}'.format(i)]=nmf_out[i]
df.head()
# Out:
#        doc0      doc1      doc2      doc3      doc4      doc5      doc6  \
# 0  0.041747  0.097581  0.119516  0.043132  0.036276  0.138458  0.060672
# 1  0.128407  0.026704  0.134599  0.237841  0.000000  0.026984  0.072844
# 2  0.000000  0.000000  0.000000  0.000000  0.009591  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.003403  0.000000
# 4  0.040015  0.038578  0.050740  0.000000  0.083087  0.032393  0.073848
#
#        doc7      doc8      doc9    ...       doc680    doc681    doc682  \
# 0  0.052036  0.053765  0.055766    ...     0.146321  0.015922  0.142514
# 1  0.000000  0.020188  0.000000    ...     0.056448  0.349375  0.024102
# 2  0.000000  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 3  0.063916  0.000000  0.000000    ...     0.000000  0.000000  0.000000
# 4  0.021251  0.088842  0.203921    ...     0.084543  0.016519  0.100362
#
#      doc683    doc684    doc685    doc686    doc687    doc688    doc689
# ...

# %%
lda = LatentDirichletAllocation(n_topics=20, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(tf)

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx))
        print (" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))
no_top_words=20
display_topics(nmf, tfidf_feature_names, no_top_words)
# Out:
# Topic 0:
# people going really think ve know things want don time way right actually kind make world little thing say work
# Topic 1:
# countries world country africa global population people america growth europe health social percent food today china child children economic states
# Topic 2:
# brain sleep right lab similar happening video behavior mental understand going different theory face body human disease ideas left mind
# Topic 3:
# music play piece applause playing video happy light everybody sound hear project make felt wonderful sounds little new patients lot
# Topic 4:
# said life people day didn story mother told family time came stories children did years thought man met young went
# Topic 5:
# design city building new water built create house nature process use working parts space school project control ideas make technology
# Topic 6:
# ...

# %%
display_topics(lda, tf_feature_names, no_top_words)
# Out:
# Topic 0:
# world people countries years country think going time change need america ve africa know life way make percent look today
# Topic 1:
# music people world health make mental care way new life applause video know years stories idea work making need person
# Topic 2:
# children kids parents study child school really going years did lives people jobs laughter good work know age time likely
# Topic 3:
# design level life city key oh million isn don god story use terms house need got growth number model past
# Topic 4:
# people going really think actually ca ve things make right thing want say know lot don world look kind way
# Topic 5:
# medical patients need people learn time really help way know learning best think work ve care control let research carbon
# Topic 6:
# brain education students people going different right think let really face make story time human college similar understand know school
# Topic 7:
# ...

# %% [markdown]
# <h1>Create dataframe with all words and vectors from google's vector space</h1>

# %%
modelvocab=WV.wv.vocab
tempdict={}
for word in list(modelvocab):
    try:tempdict[word]=word_vectors[word]
    except: pass
del word_vectors
del WV
df=pd.DataFrame.from_dict(tempdict).T

# %%
inertias=[]
silhouette=[]
n_clusters=50
for x in range(1,200):
    kmeans=KMeans(n_clusters=x)
    kmeans.fit_predict(X=df)
    inertias.append(kmeans.inertia_)
    silhouette.append(kmeans.silhouette)
    
plt.plot(inertias)
plt.show()
plt.plot(silhouette)
plt.show()

# %%
inertias=[]
silhouette=[]
n_clusters=50
for x in range(2,25):
    kmeans=KMeans(n_clusters=x)
    kmeans.fit_predict(X=df)
    inertias.append(kmeans.inertia_)
    silhouette.append(silhouette_score(X=df, labels=kmeans.labels_, metric='euclidean'))
    
plt.plot(inertias)
plt.show()
plt.plot(silhouette)
plt.show()

# %%
silhouette=[]
for x in range(5,15):
    AC=AgglomerativeClustering(n_clusters=x)
    AC.fit_predict(df)
#     inertias.append(AC.)
    silhouette.append(silhouette_score(X=df, labels=AC.labels_, metric='euclidean'))
plt.plot(silhouette)
plt.show()

# %%
AC=AgglomerativeClustering(n_clusters=8, compute_full_tree=True)
AC.fit_predict(df)
# Out:
# array([0, 2, 6, ..., 0, 0, 3])

# %%
AC.children_[0:100]
# Out:
# array([[ 4161, 10397],
#        [ 9169,  9377],
#        [ 3285,  9168],
#        [ 3997,  9376],
#        [ 6954,  9555],
#        [ 3218, 11266],
#        [11518, 11519],
#        [10376, 10738],
#        [ 3923, 11517],
#        [ 5011, 10388],
#        [10745, 11516],
#        [ 6912, 11522],
#        [ 6864,  7454],
#        [ 6882,  6932],
#        [ 6956,  9557],
#        [ 3531,  7356],
#        [ 4145, 11523],
#        [ 9039, 10371],
#        [ 4941, 10291],
#        [ 5912,  9336],
#        [ 3286, 11524],
#        [11520, 11521],
#        [ 3196, 11528],
#        [  332, 10383],
#        [ 2024, 10526],
#        [ 8866, 10233],
#        [ 9556,  9558],
#        [ 8283,  9077],
#        [ 6392, 11535],
#        [ 4164, 11533],
#        [ 4163, 10375],
#        [ 2331, 11430],
#        [ 7843,  7844],
#        [ 6331,  6488],
#        [ 9318,  9942],
#        [  223,  6662],
#        [ 5664,  6390],
#        [10754, 10937],
#        [ 2920, 10972],
#        [  652,   653],
# ...

# %%
SC=SpectralClustering(n_clusters=n_clusters)
SC.fit_predict(df)
# Out:
# array([6, 6, 0, ..., 0, 0, 8], dtype=int32)

# %% [markdown]
# <h1>Create text generator</h1>

# %%
# Small LSTM Network to Generate Text for TedTalks
import numpy
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
import pickle
import sys

# %%
# load ascii text and covert to lowercase
with open('TedAllTalksString.pickle.dat', 'rb') as pickle_file:
    raw_text = pickle.load(pickle_file)
raw_text = raw_text.lower()
# create mapping of unique chars to integers, and a reverse mapping
chars = sorted(list(set(raw_text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))
# summarize the loaded data
n_chars = len(raw_text)
n_vocab = len(chars)
print ("Total Characters: ", n_chars)
print ("Total Vocab: ", n_vocab)
# prepare the dataset of input to output pairs encoded as integers
seq_length = 100
dataX = []
dataY = []
for i in range(0, n_chars - seq_length, 1):
	seq_in = raw_text[i:i + seq_length]
	seq_out = raw_text[i + seq_length]
	dataX.append([char_to_int[char] for char in seq_in])
	dataY.append(char_to_int[seq_out])
n_patterns = len(dataX)
print ("Total Patterns: ", n_patterns)
# reshape X to be [samples, time steps, features]
X = numpy.reshape(dataX, (n_patterns, seq_length, 1))
# normalize
X = X / float(n_vocab)
# one hot encode the output variable
y = np_utils.to_categorical(dataY)
# define the LSTM model
# load the network weights
# Out:
# Total Characters:  5590185
# Total Vocab:  66

# %%
model = Sequential()
model.add(LSTM(400, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(200))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
# Out:
# [name: "/cpu:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 9157318406834247137]

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature

    exp_preds = np.exp(preds)

    preds = exp_preds / np.sum(exp_preds)

    probas = np.random.multinomial(1, preds, 1)
#     print(np.argmax(probas))
  
    return (np.argmax(probas))

# %%
filename='weights-improvement-07-1.4220.hdf5'
model.load_weights(filename)
model.compile(loss='categorical_crossentropy', optimizer='adam')
# pick a random seed
start = numpy.random.randint(0, len(dataX)-1)
pattern = dataX[start]
print ("Seed:")
print ("\"", ''.join([int_to_char[value] for value in pattern]), "\"")
# generate characters
for i in range(1000):
	x = numpy.reshape(pattern, (1, len(pattern), 1))
	x = x / float(n_vocab)
	prediction = model.predict(x, verbose=0)
# 	print(prediction)
	index=sample(prediction[0], temperature=0.5)
# 	index = numpy.argmax(prediction[0])
	result = int_to_char[index]
	seq_in = [int_to_char[value] for value in pattern]
	sys.stdout.write(result)
	pattern.append(index)
	pattern = pattern[1:len(pattern)]
print ("\nDone.")

# %% [markdown]
# <h3>Continued in other notebook</h3>

# %% [markdown]
# <h1>Recommender System</h1>

# %%
rec_df=pd.DataFrame(pd.DataFrame(tfidf.todense()))
rec_df
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.000000  0.041046  0.000000  0.000000  0.015333  0.643381  0.000000
# 1    0.018819  0.027808  0.019903  0.021729  0.072715  0.000000  0.000000
# 2    0.000000  0.023243  0.000000  0.000000  0.017365  0.000000  0.120955
# 3    0.000000  0.014977  0.000000  0.000000  0.100704  0.276176  0.000000
# 4    0.000000  0.036112  0.051693  0.000000  0.000000  0.000000  0.000000
# 5    0.000000  0.043989  0.000000  0.137492  0.098595  0.000000  0.000000
# 6    0.068420  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7    0.000000  0.182956  0.000000  0.000000  0.019527  0.000000  0.000000
# 8    0.000000  0.000000  0.000000  0.000000  0.037212  0.000000  0.064800
# 9    0.000000  0.072633  0.000000  0.000000  0.000000  0.000000  0.000000
# 10   0.000000  0.000000  0.000000  0.000000  0.041729  0.000000  0.000000
# 11   0.000000  0.000000  0.000000  0.100782  0.000000  0.000000  0.335596
# ...

# %%
def cleaner(MessyString):
    ProcessedSubs=[]
    LemmaString=''
    
    tempstring=MessyString
    tempstring=tempstring.replace('\n', ' ')
    for char in '0123456789!:",;-':
        tempstring=re.sub(char,'',tempstring)
    tempstring=re.sub('\?','',tempstring)
    tempstring=re.sub('\.','',tempstring)
    ProcessedSubs.append(tempstring)
    tempstring=tempstring.replace('\'', '')
    tempstring=tempstring.replace('  ', ' ')
    tempstring=tempstring.strip()+'\n'
    tempstring=tempstring.lower()

#     l=nltk.wordnet.WordNetLemmatizer()#doesn't work well at all
    stemmer=nltk.stem.PorterStemmer()

    wordlist=tempstring.split()
    StopWords=nltk.corpus.stopwords.words("english")
        
    templist=[]
    for word in wordlist:   
        if not word in StopWords:
#             templist.append(stemmer.stem(word)) #stemming didn't produce any better tsne models and resulted in increased numbers of words not found in google's vector space.
            templist.append(word)
    
    tfidf_vectorizer = TfidfVectorizer(max_features=N_fea, stop_words='english')
    tfidf = tfidf_vectorizer.fit_transform(templist)
    return(templist)
    
def recommender(userstring, model):

    dist=[]
    sim=[]
    spmat=tfidf_vectorizer.transform([' '.join(cleaner(userstring))])
    for i in tfidf.todense():
        dist.append(pairwise.cosine_distances(spmat, i))
        sim.append(pairwise.cosine_similarity(spmat, i))
    return(numpy.argmin(dist), min(dist), AllSubs[numpy.argmin(dist)])

# %%
userstring='house green solar'
ix, MIN, talk = recommender(userstring, tfidf.todense())
talk
# print (" ".join([tfidf_feature_names[ix] for i in topic.argsort()[:-no_top_words - 1:-1]]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-e6b94feae899> in <module>()
#       1 userstring='house green solar'
# ----> 2 ix, MIN, talk = recommender(userstring, tfidf.todense())
#       3 talk
#       4 # print (" ".join([tfidf_feature_names[ix] for i in topic.argsort()[:-no_top_words - 1:-1]]))
#
# NameError: name 'recommender' is not defined

# %%
userstring='waiting on ship to run'
ix, MIN, topic = recommender(userstring, nmf)
print(topic)
# print (" ".join([tfidf_feature_names[ix] for i in topic.argsort()[:-no_top_words - 1:-1]]))
# Out:
# 00:12
# The Olympic motto is "Citius, Altius, Fortius."
# 00:16
# Faster, Higher, Stronger.
# 00:18
# And athletes have fulfilled that motto rapidly.
# 00:22
# The winner of the 2012 Olympic marathon
# 00:25
# ran two hours and eight minutes.
# 00:28
# Had he been racing against the winner
# 00:29
# of the 1904 Olympic marathon,
# 00:32
# he would have won by nearly an hour and a half.
# 00:35
# Now we all have this feeling
# 00:37
# that we're somehow just getting better
# 00:39
# as a human race, inexorably progressing,
# 00:41
# but it's not like we've evolved into a new species
# 00:43
# in a century.
# 00:44
# So what's going on here?
# 00:47
# I want to take a look at what's really behind
# 00:48
# this march of athletic progress.
# 00:51
# In 1936, Jesse Owens
# 00:53
# held the world record in the 100 meters.
# 00:56
# Had Jesse Owens been racing last year
# 00:58
# in the world championships of the 100 meters,
# 01:01
# when Jamaican sprinter Usain Bolt finished,
# 01:03
# ...

# %%
userstring='disease world health love'
dist=[]
sim=[]
spmat=tfidf_vectorizer.transform([' '.join(cleaner(userstring))])
for i in tfidf.todense():
    dist.append(pairwise.cosine_distances(spmat, i))
    sim.append(pairwise.cosine_similarity(spmat, i))
print(numpy.argmin(dist), min(dist))
print(AllSubs[numpy.argmin(dist)])
# Out:
# 41 [[ 0.60021974]]
# 00:00
# Translator: Joseph Geni Reviewer: Camille Martínez
# 00:17
# Hi.
# 00:19
# Thank you.
# 00:20
# [Jennifer Brea is sound-sensitive.
# 00:22
# The live audience was asked to applaud ASL-style, in silence.]
# 00:25
# So, five years ago, this was me.
# 00:29
# I was a PhD student at Harvard,
# 00:31
# and I loved to travel.
# 00:34
# I had just gotten engaged to marry the love of my life.
# 00:39
# I was 28, and like so many of us when we are in good health,
# 00:43
# I felt like I was invincible.
# 00:46
# Then one day I had a fever of 104.7 degrees.
# 00:50
# I probably should have gone to the doctor,
# 00:52
# but I'd never really been sick in my life,
# 00:55
# and I knew that usually, if you have a virus,
# 00:57
# you stay home and you make some chicken soup,
# 01:00
# and in a few days, everything will be fine.
# 01:04
# But this time it wasn't fine.
# 01:07
# After the fever broke,
# 01:09
# for three weeks I was so dizzy, I couldn't leave my house.
# ...

# %%
# Out:
# (41, array([[ 0.60021974]]))

# %%
numpy.argmax(sim)
# Out:
# 41

# %%
AllSubs[41]
# Out:
# '00:00\nTranslator: Joseph Geni Reviewer: Camille Martínez\n00:17\nHi.\n00:19\nThank you.\n00:20\n[Jennifer Brea is sound-sensitive.\n00:22\nThe live audience was asked to applaud ASL-style, in silence.]\n00:25\nSo, five years ago, this was me.\n00:29\nI was a PhD student at Harvard,\n00:31\nand I loved to travel.\n00:34\nI had just gotten engaged to marry the love of my life.\n00:39\nI was 28, and like so many of us when we are in good health,\n00:43\nI felt like I was invincible.\n00:46\nThen one day I had a fever of 104.7 degrees.\n00:50\nI probably should have gone to the doctor,\n00:52\nbut I\'d never really been sick in my life,\n00:55\nand I knew that usually, if you have a virus,\n00:57\nyou stay home and you make some chicken soup,\n01:00\nand in a few days, everything will be fine.\n01:04\nBut this time it wasn\'t fine.\n01:07\nAfter the fever broke,\n01:09\nfor three weeks I was so dizzy, I couldn\'t leave my house.\n01:13\nI would walk straight into door frames.\n01:16\nI
# ...

# %% [markdown]
# <h1>Flask App</h1>

# %%
app= Flask(__name__)

@app.route('/')
def index():
    return render_template('index.html')

if __name__ == '__main__':
    app.run(debug=True,port=5401)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-430-582a15eeb9e3> in <module>()
#       7
#       8 if __name__ == '__main__':
# ----> 9     app.run(debug=True,port=5001)
#      10
#
# /home/sufyan/anaconda3/lib/python3.6/site-packages/flask/app.py in run(self, host, port, debug, **options)
#     839         options.setdefault('use_debugger', self.debug)
#     840         try:
# --> 841             run_simple(host, port, self, **options)
#     842         finally:
#     843             # reset the first request information if the development server
#
# /home/sufyan/anaconda3/lib/python3.6/site-packages/werkzeug/serving.py in run_simple(hostname, port, application, use_reloader, use_debugger, use_evalex, extra_files, reloader_interval, reloader_type, threaded, processes, request_handler, static_files, passthrough_errors, ssl_context)
# ...

# %%
pickle.dump(tfidf, open("tfidf.pickle.dat", "wb"))
AllSubs
# pickle.dump(AllSubs, open("TEDxsubs.pickle.dat", "wb"))

# %%
from flask import Flask
from flask import render_template

app= Flask(__name__)

@app.route('/')
def index():
    return render_template('index.html')

if __name__ == '__main__':
    app.run(debug=True,port=5403)

@app.route('/booyah', methods=['GET','POST'])
def booyah():
	import pickle
	import numpy
	from sklearn.metrics import pairwise
	from nltk.stem import PorterStemmer
	import re
	from nltk.corpus.stopwords import words
    
    
	with open('tfidf.pickle.dat', 'rb') as pickle_file:tfidf = pickle.load(pickle_file)

	with open('TEDxsubs.pickle.dat', 'rb') as pickle_file: AllSubs = pickle.load(pickle_file)
	def cleaner(MessyString):
		ProcessedSubs=[]
		LemmaString=''
		tempstring=MessyString
		tempstring=tempstring.replace('\n', ' ')
		for char in '0123456789!:",;-':
			tempstring=re.sub(char,'',tempstring)
		tempstring=re.sub('\?','',tempstring)
		tempstring=re.sub('\.','',tempstring)
		ProcessedSubs.append(tempstring)
		tempstring=tempstring.replace('\'', '')
		tempstring=tempstring.replace('  ', ' ')
		tempstring=tempstring.strip()+'\n'
		tempstring=tempstring.lower()
		#     l=nltk.wordnet.WordNetLemmatizer()#doesn't work well at all
		stemmer=nltk.stem.PorterStemmer()

		wordlist=tempstring.split()
		StopWords=nltk.corpus.stopwords.words("english")
		
		templist=[]
		for word in wordlist:   
			if not word in StopWords:
		#             templist.append(stemmer.stem(word)) #stemming didn't produce any better tsne models and resulted in increased numbers of words not found in google's vector space.
				templist.append(word)

		tfidf_vectorizer = TfidfVectorizer(max_features=N_fea, stop_words='english')
		tfidf = tfidf_vectorizer.fit_transform(templist)
		return(templist)

	def recommender(userstring, model):
		dist=[]
		sim=[]
		spmat=tfidf_vectorizer.transform([' '.join(cleaner(userstring))])
		for i in tfidf.todense():
			dist.append(pairwise.cosine_distances(spmat, i))
			sim.append(pairwise.cosine_similarity(spmat, i))
	return(numpy.argmin(dist), min(dist), AllSubs[numpy.argmin(dist)]) 
	ix, MIN, talk = recommender(userstring, tfidf.todense())
	return (talk)
